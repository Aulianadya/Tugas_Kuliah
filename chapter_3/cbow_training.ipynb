# %%
# !pip install gensim
# Out:
# Collecting gensim
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading gensim-4.3.3-cp312-cp312-win_amd64.whl.metadata (8.2 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim)
#   Downloading wrapt-1.17.2-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Downloading gensim-4.3.3-cp312-cp312-win_amd64.whl (24.0 MB)
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.0 MB 1.1 MB/s eta 0:00:21
#    - -------------------------------------- 0.8/24.0 MB 1.3 MB/s eta 0:00:18
#    -- ------------------------------------- 1.3/24.0 MB 1.3 MB/s eta 0:00:18
#    -- ------------------------------------- 1.6/24.0 MB 1.3 MB/s eta 0:00:18
#    --- ------------------------------------ 1.8/24.0 MB 1.3 MB/s eta 0:00:18
#    --- ------------------------------------ 1.8/24.0 MB 1.3 MB/s eta 0:00:18
#    --- ------------------------------------ 2.4/24.0 MB 1.3 MB/s eta 0:00:17
#    ---- ----------------------------------- 2.6/24.0 MB 1.3 MB/s eta 0:00:17
#    ----- ---------------------------------- 3.1/24.0 MB 1.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 3.4/24.0 MB 1.4 MB/s eta 0:00:15
#    ------ --------------------------------- 3.9/24.0 MB 1.5 MB/s eta 0:00:14
#    ------ --------------------------------- 4.2/24.0 MB 1.5 MB/s eta 0:00:13
#    ------- -------------------------------- 4.7/24.0 MB 1.6 MB/s eta 0:00:13
#    -------- ------------------------------- 5.2/24.0 MB 1.6 MB/s eta 0:00:12
#    --------- ------------------------------ 5.8/24.0 MB 1.7 MB/s eta 0:00:11
#    ---------- ----------------------------- 6.3/24.0 MB 1.7 MB/s eta 0:00:11
#    ---------- ----------------------------- 6.6/24.0 MB 1.7 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.1/24.0 MB 1.8 MB/s eta 0:00:10
#    ------------ --------------------------- 7.6/24.0 MB 1.8 MB/s eta 0:00:10
#    ------------- -------------------------- 8.4/24.0 MB 1.9 MB/s eta 0:00:09
#    -------------- ------------------------- 8.9/24.0 MB 1.9 MB/s eta 0:00:08
#    --------------- ------------------------ 9.4/24.0 MB 1.9 MB/s eta 0:00:08
#    ----------------- ---------------------- 10.2/24.0 MB 2.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 10.7/24.0 MB 2.0 MB/s eta 0:00:07
#    ------------------ --------------------- 11.3/24.0 MB 2.0 MB/s eta 0:00:07
#    ------------------- -------------------- 11.8/24.0 MB 2.0 MB/s eta 0:00:06
#    -------------------- ------------------- 12.3/24.0 MB 2.1 MB/s eta 0:00:06
#    --------------------- ------------------ 13.1/24.0 MB 2.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 13.6/24.0 MB 2.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 14.2/24.0 MB 2.1 MB/s eta 0:00:05
#    ------------------------ --------------- 14.7/24.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------- -------------- 15.2/24.0 MB 2.2 MB/s eta 0:00:05
#    -------------------------- ------------- 15.7/24.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------- ------------- 16.0/24.0 MB 2.2 MB/s eta 0:00:04
#    --------------------------- ------------ 16.5/24.0 MB 2.2 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.0/24.0 MB 2.2 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.3/24.0 MB 2.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.6/24.0 MB 2.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.6/24.0 MB 2.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 17.8/24.0 MB 2.1 MB/s eta 0:00:04
#    ------------------------------ --------- 18.1/24.0 MB 2.0 MB/s eta 0:00:03
#    ------------------------------ --------- 18.4/24.0 MB 2.0 MB/s eta 0:00:03
#    ------------------------------- -------- 18.9/24.0 MB 2.0 MB/s eta 0:00:03
#    ------------------------------- -------- 19.1/24.0 MB 2.0 MB/s eta 0:00:03
#    -------------------------------- ------- 19.7/24.0 MB 2.0 MB/s eta 0:00:03
#    --------------------------------- ------ 20.2/24.0 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 20.7/24.0 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 21.0/24.0 MB 2.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.5/24.0 MB 2.0 MB/s eta 0:00:02
#    ------------------------------------ --- 22.0/24.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 22.5/24.0 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/24.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  23.6/24.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 2.1 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.5 MB 2.8 MB/s eta 0:00:06
#    -- ------------------------------------- 1.0/15.5 MB 2.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/15.5 MB 2.9 MB/s eta 0:00:05
#    ------ --------------------------------- 2.4/15.5 MB 2.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.9/15.5 MB 2.8 MB/s eta 0:00:05
#    -------- ------------------------------- 3.4/15.5 MB 2.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/15.5 MB 2.9 MB/s eta 0:00:04
#    ------------ --------------------------- 4.7/15.5 MB 2.9 MB/s eta 0:00:04
#    -------------- ------------------------- 5.5/15.5 MB 2.9 MB/s eta 0:00:04
#    --------------- ------------------------ 6.0/15.5 MB 2.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.6/15.5 MB 3.0 MB/s eta 0:00:04
#    ------------------ --------------------- 7.3/15.5 MB 3.0 MB/s eta 0:00:03
#    -------------------- ------------------- 8.1/15.5 MB 3.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.7/15.5 MB 3.0 MB/s eta 0:00:03
#    ------------------------ --------------- 9.4/15.5 MB 3.0 MB/s eta 0:00:02
#    ------------------------- -------------- 10.0/15.5 MB 3.0 MB/s eta 0:00:02
#    --------------------------- ------------ 10.5/15.5 MB 2.9 MB/s eta 0:00:02
#    --------------------------- ------------ 10.7/15.5 MB 2.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.3/15.5 MB 2.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.5/15.5 MB 2.8 MB/s eta 0:00:02
#    ------------------------------ --------- 11.8/15.5 MB 2.8 MB/s eta 0:00:02
#    ------------------------------- -------- 12.1/15.5 MB 2.7 MB/s eta 0:00:02
#    ------------------------------- -------- 12.3/15.5 MB 2.6 MB/s eta 0:00:02
#    --------------------------------- ------ 12.8/15.5 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.5 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.5 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 2.5 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-win_amd64.whl (45.9 MB)
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/45.9 MB 2.4 MB/s eta 0:00:20
#     --------------------------------------- 1.0/45.9 MB 3.0 MB/s eta 0:00:16
#    - -------------------------------------- 1.6/45.9 MB 2.9 MB/s eta 0:00:16
#    -- ------------------------------------- 2.4/45.9 MB 2.9 MB/s eta 0:00:15
#    -- ------------------------------------- 2.9/45.9 MB 2.9 MB/s eta 0:00:15
#    -- ------------------------------------- 3.4/45.9 MB 2.9 MB/s eta 0:00:15
#    --- ------------------------------------ 4.2/45.9 MB 2.9 MB/s eta 0:00:15
#    --- ------------------------------------ 4.5/45.9 MB 2.9 MB/s eta 0:00:15
#    ---- ----------------------------------- 5.2/45.9 MB 2.8 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.8/45.9 MB 2.8 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.3/45.9 MB 2.8 MB/s eta 0:00:15
#    ------ --------------------------------- 7.1/45.9 MB 2.8 MB/s eta 0:00:14
#    ------ --------------------------------- 7.6/45.9 MB 2.8 MB/s eta 0:00:14
#    ------- -------------------------------- 8.4/45.9 MB 2.9 MB/s eta 0:00:13
#    ------- -------------------------------- 8.9/45.9 MB 2.9 MB/s eta 0:00:13
#    -------- ------------------------------- 9.7/45.9 MB 2.9 MB/s eta 0:00:13
#    --------- ------------------------------ 10.5/45.9 MB 2.9 MB/s eta 0:00:13
#    --------- ------------------------------ 11.0/45.9 MB 3.0 MB/s eta 0:00:12
#    ---------- ----------------------------- 11.8/45.9 MB 3.0 MB/s eta 0:00:12
#    ---------- ----------------------------- 12.6/45.9 MB 3.0 MB/s eta 0:00:12
#    ----------- ---------------------------- 13.1/45.9 MB 3.0 MB/s eta 0:00:11
#    ------------ --------------------------- 13.9/45.9 MB 3.0 MB/s eta 0:00:11
#    ------------ --------------------------- 14.7/45.9 MB 3.1 MB/s eta 0:00:11
#    ------------- -------------------------- 15.2/45.9 MB 3.0 MB/s eta 0:00:11
#    ------------- -------------------------- 15.5/45.9 MB 3.0 MB/s eta 0:00:11
#    ------------- -------------------------- 15.7/45.9 MB 2.9 MB/s eta 0:00:11
#    -------------- ------------------------- 16.3/45.9 MB 2.9 MB/s eta 0:00:11
#    -------------- ------------------------- 16.5/45.9 MB 2.8 MB/s eta 0:00:11
#    -------------- ------------------------- 17.0/45.9 MB 2.8 MB/s eta 0:00:11
#    --------------- ------------------------ 17.6/45.9 MB 2.8 MB/s eta 0:00:11
#    --------------- ------------------------ 18.1/45.9 MB 2.8 MB/s eta 0:00:10
#    ---------------- ----------------------- 18.6/45.9 MB 2.8 MB/s eta 0:00:10
#    ---------------- ----------------------- 19.1/45.9 MB 2.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.7/45.9 MB 2.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 20.2/45.9 MB 2.8 MB/s eta 0:00:10
#    ------------------ --------------------- 20.7/45.9 MB 2.8 MB/s eta 0:00:10
#    ------------------ --------------------- 21.5/45.9 MB 2.8 MB/s eta 0:00:09
#    ------------------- -------------------- 22.0/45.9 MB 2.8 MB/s eta 0:00:09
#    ------------------- -------------------- 22.5/45.9 MB 2.8 MB/s eta 0:00:09
#    -------------------- ------------------- 23.1/45.9 MB 2.8 MB/s eta 0:00:09
#    -------------------- ------------------- 23.6/45.9 MB 2.7 MB/s eta 0:00:09
#    --------------------- ------------------ 24.4/45.9 MB 2.8 MB/s eta 0:00:08
#    --------------------- ------------------ 24.9/45.9 MB 2.8 MB/s eta 0:00:08
#    ---------------------- ----------------- 25.7/45.9 MB 2.8 MB/s eta 0:00:08
#    ---------------------- ----------------- 26.2/45.9 MB 2.8 MB/s eta 0:00:08
#    ----------------------- ---------------- 26.7/45.9 MB 2.8 MB/s eta 0:00:07
#    ----------------------- ---------------- 27.5/45.9 MB 2.8 MB/s eta 0:00:07
#    ------------------------ --------------- 28.0/45.9 MB 2.8 MB/s eta 0:00:07
#    ------------------------ --------------- 28.6/45.9 MB 2.8 MB/s eta 0:00:07
#    ------------------------- -------------- 29.4/45.9 MB 2.8 MB/s eta 0:00:06
#    -------------------------- ------------- 29.9/45.9 MB 2.8 MB/s eta 0:00:06
#    -------------------------- ------------- 30.4/45.9 MB 2.8 MB/s eta 0:00:06
#    --------------------------- ------------ 31.2/45.9 MB 2.8 MB/s eta 0:00:06
#    --------------------------- ------------ 31.7/45.9 MB 2.8 MB/s eta 0:00:06
#    ---------------------------- ----------- 32.5/45.9 MB 2.8 MB/s eta 0:00:05
#    ---------------------------- ----------- 33.0/45.9 MB 2.8 MB/s eta 0:00:05
#    ----------------------------- ---------- 33.8/45.9 MB 2.8 MB/s eta 0:00:05
#    ------------------------------ --------- 34.6/45.9 MB 2.8 MB/s eta 0:00:05
#    ------------------------------ --------- 35.1/45.9 MB 2.8 MB/s eta 0:00:04
#    ------------------------------- -------- 35.9/45.9 MB 2.8 MB/s eta 0:00:04
#    ------------------------------- -------- 36.4/45.9 MB 2.8 MB/s eta 0:00:04
#    -------------------------------- ------- 37.2/45.9 MB 2.8 MB/s eta 0:00:04
#    -------------------------------- ------- 37.7/45.9 MB 2.9 MB/s eta 0:00:03
#    --------------------------------- ------ 38.5/45.9 MB 2.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 39.3/45.9 MB 2.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 40.1/45.9 MB 2.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 40.6/45.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------ --- 41.4/45.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------ --- 42.2/45.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 42.7/45.9 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 43.5/45.9 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 44.0/45.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  44.8/45.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  45.6/45.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 45.9/45.9 MB 2.9 MB/s eta 0:00:00
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading wrapt-1.17.2-cp312-cp312-win_amd64.whl (38 kB)
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1 smart-open-7.1.0 wrapt-1.17.2

# %%
from gensim.models import Word2Vec
from nltk.corpus import abc
import nltk

# %%
print(nltk.data.find('corpora/abc'))
# Out:
# C:\Users\ASUS\AppData\Roaming\nltk_data\corpora\abc

# %%
files_list = abc.fileids()
print(files_list)
# Out:
# ['rural.txt', 'science.txt']

# %%
tokenized_documents = []
for file_ in files_list:
    text_data = abc.raw(file_).lower()
    sentence = nltk.sent_tokenize(text_data)
    tokenized_documents += [nltk.word_tokenize(sentence) for sentence in sentence]

# %%
print(tokenized_documents[0])
# Out:
# ['pm', 'denies', 'knowledge', 'of', 'awb', 'kickbacks', 'the', 'prime', 'minister', 'has', 'denied', 'he', 'knew', 'awb', 'was', 'paying', 'kickbacks', 'to', 'iraq', 'despite', 'writing', 'to', 'the', 'wheat', 'exporter', 'asking', 'to', 'be', 'kept', 'fully', 'informed', 'on', 'iraq', 'wheat', 'sales', '.']

# %%
len(tokenized_documents)
# Out:
# 28728

# %%
cbow_model = Word2Vec(sentences=tokenized_documents, vector_size=100, window=3, min_count=3, sg=0)

# %%
news_vector = cbow_model.wv['news']
print(f"Vector for 'news': {news_vector}")
# Out:
# Vector for 'news': [-0.35157102  0.47786865 -0.21595207  0.20841748 -0.07085571 -0.33214435
#  -0.03923043  0.6538184  -0.10355262 -0.28971955 -0.03859881 -0.23194762
#  -0.18951486  0.35738456  0.08429314 -0.29977167 -0.04756181 -0.15689489
#   0.03608704 -0.6493062   0.02872829  0.3787054   0.5317019  -0.5077823
#  -0.04586595  0.0525024  -0.2015636   0.19446532 -0.25478706 -0.2290919
#   0.2954932  -0.16272709  0.30218887 -0.15250051 -0.1847737   0.64734614
#   0.38537973 -0.11104473 -0.19228978 -0.18496062  0.155123   -0.3997783
#  -0.33970013 -0.10482048  0.53326595  0.0895753  -0.37188405 -0.2511892
#   0.10564489  0.09461851  0.18546863  0.05692213  0.2290868   0.11404113
#  -0.33804682 -0.1439755   0.2009459  -0.19671488 -0.54743904  0.2969078
#  -0.11335091  0.07928003 -0.0384334   0.05151806 -0.40091637  0.24131162
#  -0.15977144  0.177407   -0.5402073   0.79110616 -0.08269576 -0.00446053
#   0.51432574  0.02467754  0.5230189  -0.38212234  0.03738483  0.05217879
#  -0.31495792 -0.03306693 -0.03497459 -0.2622011  -0.37684613  0.43811902
#   0.02671185  0.01276443  0.32127246 -0.03365526  0.36845195  0.13396843
#   0.80328196  0.13741723  0.31969965 -0.2047972   0.30731305 -0.00884719
#  -0.09491799 -0.5101548  -0.0201506  -0.15917893]

# %%
similar_words = cbow_model.wv.most_similar('found')
print(similar_words)
# Out:
# [('discovered', 0.9245067238807678), ('reported', 0.8415536284446716), ('identified', 0.8336350917816162), ('observed', 0.7897452116012573), ('shown', 0.780366063117981), ('confirmed', 0.7708601951599121), ('recently', 0.7702958583831787), ('involved', 0.7547187805175781), ('reached', 0.7516522407531738), ('left', 0.7364248633384705)]

# %%
similar_words = cbow_model.wv.most_similar('professor')
print(similar_words)
# Out:
# [('dr', 0.980886697769165), ('director', 0.9463285803794861), ('assistant', 0.9365682005882263), ('executive', 0.9360519051551819), ('chief', 0.9344135522842407), ('richard', 0.9285402894020081), ('associate', 0.9266301989555359), ('john', 0.9246437549591064), ('roach', 0.9208798408508301), ('kathy', 0.9193843603134155)]

# %%
similar_words = cbow_model.wv.most_similar('think')
print(similar_words)
# Out:
# [('guess', 0.9355839490890503), ('...', 0.9184550046920776), ("'m", 0.8937014937400818), ('reckon', 0.8859682679176331), ('know', 0.8805950284004211), ('am', 0.8715969324111938), ('believe', 0.864496648311615), ('mean', 0.8616921305656433), ('saying', 0.8546046614646912), ('``', 0.8545101881027222)]

# %%
similar_words = cbow_model.wv.most_similar('grain')
print(similar_words)
# Out:
# [('wool', 0.9184401035308838), ('exports', 0.8950826525688171), ('fruit', 0.8908836245536804), ('local', 0.8847230672836304), ('cattle', 0.8819143176078796), ('sheep', 0.8773764967918396), ('beef', 0.8699753284454346), ('producers', 0.8676534295082092), ('production', 0.8632697463035583), ('grape', 0.8616906404495239)]

# %%
cbow_model.save("cbow_model_abc.model")

# %%
loaded_model = Word2Vec.load("cbow_model_abc.model")

# %%
news_vector = loaded_model.wv['news']
print(f"Vector for 'news': {news_vector}")
# Out:
# Vector for 'news': [-0.35157102  0.47786865 -0.21595207  0.20841748 -0.07085571 -0.33214435
#  -0.03923043  0.6538184  -0.10355262 -0.28971955 -0.03859881 -0.23194762
#  -0.18951486  0.35738456  0.08429314 -0.29977167 -0.04756181 -0.15689489
#   0.03608704 -0.6493062   0.02872829  0.3787054   0.5317019  -0.5077823
#  -0.04586595  0.0525024  -0.2015636   0.19446532 -0.25478706 -0.2290919
#   0.2954932  -0.16272709  0.30218887 -0.15250051 -0.1847737   0.64734614
#   0.38537973 -0.11104473 -0.19228978 -0.18496062  0.155123   -0.3997783
#  -0.33970013 -0.10482048  0.53326595  0.0895753  -0.37188405 -0.2511892
#   0.10564489  0.09461851  0.18546863  0.05692213  0.2290868   0.11404113
#  -0.33804682 -0.1439755   0.2009459  -0.19671488 -0.54743904  0.2969078
#  -0.11335091  0.07928003 -0.0384334   0.05151806 -0.40091637  0.24131162
#  -0.15977144  0.177407   -0.5402073   0.79110616 -0.08269576 -0.00446053
#   0.51432574  0.02467754  0.5230189  -0.38212234  0.03738483  0.05217879
#  -0.31495792 -0.03306693 -0.03497459 -0.2622011  -0.37684613  0.43811902
#   0.02671185  0.01276443  0.32127246 -0.03365526  0.36845195  0.13396843
#   0.80328196  0.13741723  0.31969965 -0.2047972   0.30731305 -0.00884719
#  -0.09491799 -0.5101548  -0.0201506  -0.15917893]
